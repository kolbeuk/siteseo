# %%
import requests
from bs4 import BeautifulSoup

def get_urls_from_sitemap(sitemap_url):
    response = requests.get(sitemap_url)
    soup = BeautifulSoup(response.content, 'xml')
    urls = [loc.text for loc in soup.find_all('loc')]
    return urls

def keywords_in_url(url, keywords):
    response = requests.get(url)
    keywords_found = []
    for keyword in keywords:
        if keyword.lower() in response.text.lower():
            keywords_found.append(keyword)
    return keywords_found

def load_keywords_from_file(filename):
    with open(filename, 'r') as file:
        return [line.strip() for line in file if line.strip()]

def main():
    sitemap_url = 'https://www.davidkolbconsultancy.com/blog-posts-sitemap.xml'  # Replace with the actual sitemap URL
    keywords = load_keywords_from_file('keywords.txt')
    keywords_not_found = set(keywords)

    urls = get_urls_from_sitemap(sitemap_url)
    for url in urls:
        found_keywords = keywords_in_url(url, keywords)
        if found_keywords:
            for keyword in found_keywords:
                print(f"Keyword '{keyword}' found in {url}")
                keywords_not_found.discard(keyword)

    if keywords_not_found:
        print("\nExceptions:")
        for keyword in keywords_not_found:
            print(f"Keyword '{keyword}' was not found in any URL.")

if __name__ == '__main__':
    main()
# Out:
# Keyword 'human centered' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# Keyword 'human centered design' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# Keyword 'design thinking 101' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# Keyword 'Porter's Generic Competitive Strategies' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# Keyword 'Digital Bank' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# Keyword 'Artificial Intelligence' found in https://www.davidkolbconsultancy.com/post/an-introduction-to-porter-s-generic-competitive-strategies
# ...
